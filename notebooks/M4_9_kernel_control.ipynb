# %% [markdown]
# # Milestone 4.9: Kernel Control
#
# Kernel = engine that runs code and stores variables in memory.

# %%
a = 10

# %%
b = 5

# %%
print("Sum:", a + b)

# %% [markdown]
# ## Hidden State Test
# 1. Restart kernel.
# 2. Run only the last cell.
# 3. Observe `NameError` because variables were cleared.

# %% [markdown]
# ## Interrupt vs Restart
# - Interrupt: stop current running cell
# - Restart: clear all memory and start clean
