# %% [markdown]
# # Milestone 4.10: Markdown Basics

# %% [markdown]
# ## Headings
# ### Subheading Example

# %% [markdown]
# ## Lists
# - Unordered item 1
# - Unordered item 2
#
# 1. Ordered step 1
# 2. Ordered step 2

# %% [markdown]
# Use inline code like `x` and `print()` inside explanations.

# %% [markdown]
# ```python
# x = 5
# print(x)
# ```
#
# This is a Markdown code block for explanation only.

# %%
x = 5
print("Executed from a Code cell:", x)
