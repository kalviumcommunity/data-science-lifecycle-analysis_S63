# %% [markdown]
# # Milestone 4.8: Code vs Markdown Cells

# %% [markdown]
# Code cells execute logic.
#
# Markdown cells explain purpose and interpretation.

# %%
x = 5
print("Value of x:", x)

# %% [markdown]
# The output appears because this was a **Code** cell.
#
# Rule: **Code = what you do, Markdown = why you do it.**
