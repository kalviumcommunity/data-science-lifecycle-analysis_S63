# %% [markdown]
# # Milestone 4.7: Jupyter Interface Basics
#
# This notebook validates launching Jupyter and running the first cell.

# %% [markdown]
# ## Interface Checklist
# - Home page shows files/folders
# - Path/breadcrumb visible
# - `New` button visible
# - Notebook opened successfully

# %%
print("Hello, Jupyter!")

# %% [markdown]
# Save this notebook as `M4_7_jupyter_interface.ipynb` and reopen it from Jupyter Home to confirm file management.
